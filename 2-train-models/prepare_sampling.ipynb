# %% [markdown]
# Install packages

# %%
# !module load py-mpi4py
# !pip install mpi4py

# %%
# !pip install fastparquet mplsoccer
# Out:
# Requirement already satisfied: fastparquet in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (2024.11.0)
# Requirement already satisfied: mplsoccer in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (1.4.0)
# Requirement already satisfied: pandas>=1.5.0 in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from fastparquet) (2.2.3)
# Requirement already satisfied: numpy in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from fastparquet) (2.1.3)
# Requirement already satisfied: cramjam>=2.3 in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from fastparquet) (2.9.1)
# Requirement already satisfied: fsspec in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from fastparquet) (2025.3.0)
# Requirement already satisfied: packaging in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from fastparquet) (24.2)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from mplsoccer) (3.10.1)
# Requirement already satisfied: pillow in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from mplsoccer) (11.1.0)
# Requirement already satisfied: requests in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from mplsoccer) (2.32.3)
# Requirement already satisfied: scipy in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from mplsoccer) (1.15.2)
# Requirement already satisfied: seaborn in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from mplsoccer) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from matplotlib>=3.6->mplsoccer) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from matplotlib>=3.6->mplsoccer) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from matplotlib>=3.6->mplsoccer) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from matplotlib>=3.6->mplsoccer) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from matplotlib>=3.6->mplsoccer) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from matplotlib>=3.6->mplsoccer) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from pandas>=1.5.0->fastparquet) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from pandas>=1.5.0->fastparquet) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from requests->mplsoccer) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from requests->mplsoccer) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from requests->mplsoccer) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from requests->mplsoccer) (2025.1.31)
# Requirement already satisfied: six>=1.5 in c:\users\kwvanarem\documents\onderzoek\xthreat-error-quantification\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->mplsoccer) (1.17.0)

# %% [markdown]
# Load packages

# %%
import time
import sys, os
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
# from mpi4py import MPI

# %%
sys.path.append("../xthreat-research-v1")

# %%
from xThreat import xThreat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from xThreat import xThreat
#
# ModuleNotFoundError: No module named 'xThreat'

# %% [markdown]
# Specify the parameters for the sampling

# %%
# Specify the sample sizes, the grids and the number of bootstraps
sample_sizes = [
    4000000, 1_300_000,  630_000,  370_000,  240_000,  170_000,  130_000,  100_000,
    ]
grid_sizes = [
    (16, 12), (32, 24), (40, 30), (48, 36), (56, 42), (64, 48), # The last one takes a large amount of time
              ]
n_bootstraps = 1000 # Total number of bootstraps
bootstrap_range = 500 # The bootstraps performed in this notebook

# %%
data_path = 'xThreat_data_v2.parquet'
df_events = pd.read_parquet(data_path, engine='fastparquet')

df_events['shot'] = ~df_events['shot_outcome'].isna()
df_events['goal'] = df_events['shot_outcome'] == 'Goal'

df_events.drop(columns=['id', 'shot_outcome', 'possession'], inplace=True)
df_size_bytes = df_events.memory_usage(deep=True).sum()
df_size_mb = df_size_bytes / (1024 ** 2)  # Convert to MB
print(f"DataFrame size: {df_size_mb:.2f} MB")

# %% [markdown]
# Import the data

# %%
data_path = '../1-data-preparation/data-storage/xThreat_data_v3.parquet'
df_events = pd.read_parquet(data_path, engine='fastparquet')

df_events['shot'] = ~df_events['shot_outcome'].isna()
df_events['goal'] = df_events['shot_outcome'] == 'Goal'

df_events.drop(columns=['id', 'shot_outcome', 'possession'], inplace=True)
df_size_bytes = df_events.memory_usage(deep=True).sum()
df_size_mb = df_size_bytes / (1024 ** 2)  # Convert to MB
print(f"DataFrame size: {df_size_mb:.2f} MB")
print(df_events.summary())
# Out:
# DataFrame size: 1039.54 MB
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22908\1559970389.py in ?()
#       7 df_events.drop(columns=['id', 'shot_outcome', 'possession'], inplace=True)
#       8 df_size_bytes = df_events.memory_usage(deep=True).sum()
#       9 df_size_mb = df_size_bytes / (1024 ** 2)  # Convert to MB
#      10 print(f"DataFrame size: {df_size_mb:.2f} MB")
# ---> 11 print(df_events.summary())
#
# c:\Users\kwvanarem\Documents\Onderzoek\xthreat-error-quantification\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'summary'

# %%
df_events.shape
# Out:
# (3985659, 21)

# %%
3985659/2442*380
# Out:
# 620209.0171990172

# %%
# Train an xThreat model and apply _filter_out_of_bounds.
# In this way, the other models won't have to do that during fit.
# Will speed up computations.
xThreat_prefit = xThreat(16, 12)
xThreat_prefit.fit(df_events)
df_events = xThreat_prefit._filter_out_of_bounds(df_events)
# Out:
# Filtered out 3 events that had coordinates out of bounds.
# In this, there were 0 shots and 0 goals.
# Filtered out 3 events that had coordinates out of bounds.
# In this, there were 0 shots and 0 goals.

# %% [markdown]
# Assign a random_state to each situation.

# %%
# Create a list with all combinations and assign a unique random_state
sampling_params = {}
for n_x, n_y in grid_sizes:
    for sample_size in sample_sizes:
        for i_bootstrap in range(n_bootstraps):
            random_state = 42 + (n_x + n_y) * n_bootstraps * 42 + sample_size
            sampling_params[(sample_size, n_x, n_y, i_bootstrap)] = random_state
print(len(sampling_params))
# Out:
# 960

# %%
cell_begin_time = time.time()

max_size_store_trans_matr = 0
sum_size_store_trans_matr = 0
n = 0

sampled_params = {}

for n_x, n_y in grid_sizes:
    begin_time = time.time()
    
    # Fit the 'true' xThreat model
    xT_true = xThreat(n_x, n_y)
    xT_true.fit(df_events, filter_events=False, convergence_threshold=1e-9)

    for sample_size in sample_sizes:
        for i_bootstrap in range(n_bootstraps):
            
            # Sample from the true model
            random_state = sampling_params[(sample_size, n_x, n_y, i_bootstrap)]
            df_sample = xT_true.sample(sample_size, random_state=random_state)

            # Fit a model on the sample
            xT_resampled = xThreat(n_x, n_y)
            xT_resampled.fit(df_sample)

            # Save the resampled method
            xT_resampled.save_to_pickle(f'model-storage/xt-N{sample_size}-n_x{n_x}-n_y{n_y}-i_bootstrap{i_bootstrap}-random_state{random_state}.pickle' )

            # Keep track of the storage size of the models
            max_size_store_trans_matr = max(max_size_store_trans_matr, sys.getsizeof(xT_resampled.transition_matrix))
            n += 1
            sum_size_store_trans_matr += sys.getsizeof(xT_resampled.transition_matrix)
    
    # Print the time it took to do the samples for this grid size
    hours, remainder = divmod(time.time()-begin_time, 3600)
    minutes, seconds = divmod(remainder, 60)
    print(f'Performed the {n_bootstraps} bootstrap with grid {(n_x, n_y)} within {int(hours)}h, {int(minutes)}m, {int(seconds)}s.\n')

# Print the time it took to do the sampling
hours, remainder = divmod(time.time()-cell_begin_time, 3600)
minutes, seconds = divmod(remainder, 60)
print(f'The whole resampling process took {int(hours)}h, {int(minutes)}m, {int(seconds)}s')
print(f'The maximal size of the transition matrix was {max_size_store_trans_matr/1024**2:.2f}MB')
print(f'The average size of the transition matrix was {sum_size_store_trans_matr/n/1024**2:.2f}MB')
# Out:
# Performed the 20 bootstrap with grid (16, 12) within 0h, 0m, 40s.
#
# Performed the 20 bootstrap with grid (32, 24) within 0h, 0m, 45s.
#
# Performed the 20 bootstrap with grid (40, 30) within 0h, 0m, 51s.
#
# Performed the 20 bootstrap with grid (48, 36) within 0h, 0m, 59s.
#
# Performed the 20 bootstrap with grid (56, 42) within 0h, 1m, 20s.
#
# Performed the 20 bootstrap with grid (64, 48) within 0h, 1m, 36s.
#
# The whole resampling process took 0h, 6m, 14s
# The maximal size of the transition matrix was 72.09MB
# The average size of the transition matrix was 25.51MB

# %%
3*60/4
# Out:
# 45.0

# %%
## 10 took 3:38min

# %%
1000/20
# Out:
# 50.0

# %%
50*6.5/60
# Out:
# 5.416666666666667
