# %%
import sys
import numpy as np

sys.path.append("../")
from xThreat import xThreat

# %%
xT_values = np.array([
    [0.003, 0.003, 0.003, 0.004, 0.005, 0.004, 0.004, 0.005, 0.004, 0.003, 0.003, 0.002],
    [0.004, 0.005, 0.003, 0.004, 0.005, 0.005, 0.005, 0.006, 0.005, 0.004, 0.003, 0.003],
    [0.003, 0.004, 0.003, 0.004, 0.006, 0.007, 0.007, 0.007, 0.005, 0.004, 0.004, 0.004],
    [0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.005, 0.005, 0.004, 0.004, 0.004, 0.004],
    [0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.005, 0.005, 0.004, 0.005, 0.005, 0.005],
    [0.005, 0.005, 0.006, 0.006, 0.006, 0.006, 0.005, 0.006, 0.006, 0.006, 0.006, 0.006],
    [0.007, 0.007, 0.007, 0.007, 0.007, 0.008, 0.008, 0.008, 0.008, 0.008, 0.008, 0.007],
    [0.008, 0.008, 0.009, 0.009, 0.010, 0.009, 0.010, 0.009, 0.009, 0.010, 0.010, 0.008],
    [0.010, 0.011, 0.012, 0.012, 0.013, 0.013, 0.012, 0.014, 0.013, 0.013, 0.012, 0.011],
    [0.013, 0.015, 0.016, 0.016, 0.017, 0.017, 0.019, 0.018, 0.017, 0.016, 0.015, 0.014],
    [0.018, 0.020, 0.022, 0.023, 0.025, 0.025, 0.025, 0.024, 0.024, 0.024, 0.022, 0.019],
    [0.025, 0.029, 0.034, 0.034, 0.033, 0.033, 0.035, 0.037, 0.036, 0.036, 0.031, 0.026],
    [0.037, 0.042, 0.046, 0.044, 0.048, 0.052, 0.042, 0.046, 0.047, 0.049, 0.044, 0.039],
    [0.048, 0.056, 0.067, 0.068, 0.068, 0.089, 0.116, 0.077, 0.065, 0.068, 0.060, 0.051],
    [0.060, 0.075, 0.094, 0.089, 0.126, 0.171, 0.176, 0.124, 0.096, 0.096, 0.077, 0.063],
    [0.066, 0.092, 0.103, 0.123, 0.158, 0.413, 0.371, 0.158, 0.126, 0.136, 0.094, 0.068],
])

# %%
xT_values.shape
# Out:
# (16, 12)

# %%
xT_true_16x12 = xThreat.load_from_pickle(f'../2-train-models/model-storage/true-models/xt-full-data-n_x{16}-n_y{12}.pickle')

# %%
xT_true_16x12.xT.shape
# Out:
# (192,)

# %%
xT_singh = xT_true_16x12.copy()
xT_singh.xT = np.flipud(np.transpose(xT_values)).flatten()
xT_singh.plot_xThreat()

# %%
xT_singh.plot_xThreat(cmap='viridis', edgecolors='white', edge_alpha=0.05, linewidths=0.01)

# %%
xT_values.flatten()
# Out:
# array([0.003, 0.003, 0.003, 0.004, 0.005, 0.004, 0.004, 0.005, 0.004,
#        0.003, 0.003, 0.002, 0.004, 0.005, 0.003, 0.004, 0.005, 0.005,
#        0.005, 0.006, 0.005, 0.004, 0.003, 0.003, 0.003, 0.004, 0.003,
#        0.004, 0.006, 0.007, 0.007, 0.007, 0.005, 0.004, 0.004, 0.004,
#        0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.005, 0.005, 0.004,
#        0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004, 0.004,
#        0.005, 0.005, 0.004, 0.005, 0.005, 0.005, 0.005, 0.005, 0.006,
#        0.006, 0.006, 0.006, 0.005, 0.006, 0.006, 0.006, 0.006, 0.006,
#        0.007, 0.007, 0.007, 0.007, 0.007, 0.008, 0.008, 0.008, 0.008,
#        0.008, 0.008, 0.007, 0.008, 0.008, 0.009, 0.009, 0.01 , 0.009,
#        0.01 , 0.009, 0.009, 0.01 , 0.01 , 0.008, 0.01 , 0.011, 0.012,
#        0.012, 0.013, 0.013, 0.012, 0.014, 0.013, 0.013, 0.012, 0.011,
#        0.013, 0.015, 0.016, 0.016, 0.017, 0.017, 0.019, 0.018, 0.017,
#        0.016, 0.015, 0.014, 0.018, 0.02 , 0.022, 0.023, 0.025, 0.025,
#        0.025, 0.024, 0.024, 0.024, 0.022, 0.019, 0.025, 0.029, 0.034,
#        0.034, 0.033, 0.033, 0.035, 0.037, 0.036, 0.036, 0.031, 0.026,
#        0.037, 0.042, 0.046, 0.044, 0.048, 0.052, 0.042, 0.046, 0.047,
#        0.049, 0.044, 0.039, 0.048, 0.056, 0.067, 0.068, 0.068, 0.089,
#        0.116, 0.077, 0.065, 0.068, 0.06 , 0.051, 0.06 , 0.075, 0.094,
#        0.089, 0.126, 0.171, 0.176, 0.124, 0.096, 0.096, 0.077, 0.063,
#        0.066, 0.092, 0.103, 0.123, 0.158, 0.413, 0.371, 0.158, 0.126,
#        0.136, 0.094, 0.068])
