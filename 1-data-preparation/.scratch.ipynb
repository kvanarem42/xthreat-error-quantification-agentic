# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt

from datadownloader import DataDownloader
from datasetcreator import columns_to_keep, DataSetCreator

# %%
df_v4 = pd.read_parquet('data-storage/xThreat_data_v4.parquet')
df_v3 = pd.read_parquet('data-storage/xThreat_data_v3.parquet')

# %%
df_v4.describe()
# Out:
#                   x             y    possession  possession_length  \
# count  3.985659e+06  3.985659e+06  3.985659e+06       3.985659e+06
# mean   5.132544e+01  3.383289e+01  9.481095e+01       1.023497e+01
# std    2.319977e+01  1.937700e+01  5.628464e+01       1.144458e+01
# min    8.750000e-02  8.500000e-02  2.000000e+00       0.000000e+00
# 25%    3.482500e+01  1.700000e+01  4.600000e+01       3.000000e+00
# 50%    5.057500e+01  3.374500e+01  9.300000e+01       7.000000e+00
# 75%    6.833750e+01  5.066000e+01  1.410000e+02       1.400000e+01
# max    1.049125e+02  6.791500e+01  2.730000e+02       2.300000e+02
#
#        chain_length      match_id        period     player_id  \
# count  3.985659e+06  3.985659e+06  3.985659e+06  3.985659e+06
# mean   6.102686e+00  3.033199e+06  1.490277e+00  1.589834e+04
# std    7.992756e+00  1.533470e+06  4.999055e-01  4.423549e+04
# min    0.000000e+00  9.575000e+03  1.000000e+00  2.935000e+03
# ...

# %%
df_v3.describe()
# Out:
#                   x             y    possession  possession_length  \
# count  3.985659e+06  3.985659e+06  3.985659e+06       3.985659e+06
# mean   5.132544e+01  3.383289e+01  9.481095e+01       1.023497e+01
# std    2.319977e+01  1.937700e+01  5.628464e+01       1.144458e+01
# min    8.750000e-02  8.500000e-02  2.000000e+00       0.000000e+00
# 25%    3.482500e+01  1.700000e+01  4.600000e+01       3.000000e+00
# 50%    5.057500e+01  3.374500e+01  9.300000e+01       7.000000e+00
# 75%    6.833750e+01  5.066000e+01  1.410000e+02       1.400000e+01
# max    1.049125e+02  6.791500e+01  2.730000e+02       2.300000e+02
#
#        chain_length      match_id        period     player_id  \
# count  3.985659e+06  3.985659e+06  3.985659e+06  3.985659e+06
# mean   6.102686e+00  3.033199e+06  1.490277e+00  1.589834e+04
# std    7.992756e+00  1.533470e+06  4.999055e-01  4.423549e+04
# min    0.000000e+00  9.575000e+03  1.000000e+00  2.935000e+03
# ...

# %%
# Investigate the differences between the two versions
print("Columns in v4 but not in v3:", set(df_v4.columns) - set(df_v3.columns))
print("Columns in v3 but not in v4:", set(df_v3.columns) - set(df_v4.columns))

# Investigate the differences of the values.

for col in df_v3.columns:
    if col in df_v4.columns:
        print(f"Column: {col}")
        # print("v3 unique values:", df_v3[col].unique())
        # print("v4 unique values:", df_v4[col].unique())
        print(f"{np.sum(df_v3[col] != df_v4[col])}")  # This will show how many rows are different
        print("\n")
# Out:
# Columns in v4 but not in v3: {'position'}
# Columns in v3 but not in v4: set()
# Column: x
# 0
#
#
# Column: y
# 0
#
#
# Column: possession_kept
# 0
#
#
# Column: possession
# 0
#
#
# Column: possession_length
# 0
#
#
# Column: chain_length
# 0
#
#
# Column: previous_deleted
# 0
#
#
# Column: match_id
# 0
#
#
# Column: id
# 0
#
#
# Column: period
# 0
#
#
# Column: player_id
# 0
#
#
# Column: type
# 0
#
#
# Column: shot_outcome
# 3956799
#
#
# Column: shot_statsbomb_xg
# 3956799
#
#
# Column: pass_height
# 1911526
#
#
# Column: under_pressure
# 2963142
#
#
# Column: next_type
# 0
#
#
# Column: next_x
# 0
#
#
# Column: next_y
# 0
#
#
# Column: next_under_pressure
# 2962808
#
#
# Column: next_team_id
# 0
#
#
# Column: next_player_id
# 0

# %%
df_test = pd.read_parquet("data-storage/raw_data/7-Ligue 1/27-2015_2016/3829413-2015-08-07-Lille(0)-Paris Saint-Germain(1).parquet")

# %%
df_test.columns.tolist()
# Out:
# ['ball_receipt_outcome',
#  'ball_recovery_offensive',
#  'ball_recovery_recovery_failure',
#  'block_deflection',
#  'block_offensive',
#  'carry_end_location',
#  'clearance_aerial_won',
#  'clearance_body_part',
#  'clearance_head',
#  'clearance_left_foot',
#  'clearance_right_foot',
#  'counterpress',
#  'dribble_no_touch',
#  'dribble_nutmeg',
#  'dribble_outcome',
#  'dribble_overrun',
#  'duel_outcome',
#  'duel_type',
#  'duration',
#  'foul_committed_advantage',
#  'foul_committed_card',
#  'foul_committed_type',
#  'foul_won_advantage',
#  'foul_won_defensive',
#  'goalkeeper_body_part',
#  'goalkeeper_end_location',
#  'goalkeeper_lost_in_play',
#  'goalkeeper_outcome',
#  'goalkeeper_position',
#  'goalkeeper_technique',
#  'goalkeeper_type',
#  'id',
#  'index',
#  'interception_outcome',
#  'location',
#  'match_id',
#  'minute',
#  'off_camera',
#  'out',
#  'pass_aerial_won',
#  'pass_angle',
#  'pass_assisted_shot_id',
#  'pass_body_part',
#  'pass_cross',
# ...

# %%
df_test['position']
# Out:
# 6           Right Center Midfield
# 7                  Center Forward
# 1796    Center Defensive Midfield
# 8       Center Defensive Midfield
# 1797             Left Center Back
#                   ...
# 932                Center Forward
# 3005          Left Center Forward
# 2541          Left Center Forward
# 3339                         None
# 3340                         None
# Name: position, Length: 1933, dtype: object

# %%
df_test = pd.read_parquet("data-storage/xThreat_data_v4_ligue1_1516.parquet", engine='fastparquet')

# %%
df_test.head()
# Out:
#              x       y  possession_kept  possession_length  chain_length  \
# index
# 8      37.6250  34.085             True                  0             0
# 1797   26.0750  28.305             True                  1             1
# 9      25.6375  30.260             True                  2             2
# 1798   24.2375  45.220             True                  3             3
# 10     27.7375  49.045             True                  4             4
#
#        previous_deleted  match_id  period  player_id   type  ...  \
# index                                                        ...
# 8                  True   3829413       1     3026.0   Pass  ...
# 1797              False   3829413       1     3956.0  Carry  ...
# 9                 False   3829413       1     3956.0   Pass  ...
# 1798              False   3829413       1     3295.0  Carry  ...
# 10                False   3829413       1     3295.0   Pass  ...
#
# ...

# %%
df_test2 = pd.read_parquet("data-storage/xThreat_data_v4_euros2020.parquet", engine='fastparquet')
df_test2.head()
# Out:
#              x       y  possession_kept  possession  possession_length  \
# index
# 2088   13.8250   6.375             True           3                  0
# 9       2.8875  10.795             True           3                  2
# 2089    6.9125  30.770             True           3                  3
# 10      7.9625  33.065             True           3                  4
# 2090   17.2375  40.715             True           3                  5
#
#        chain_length  previous_deleted  match_id  \
# index
# 2088              0              True   3788741
# 9                 1             False   3788741
# 2089              2             False   3788741
# 10                3             False   3788741
# 2090              4             False   3788741
#
#                                          id  period  ...  shot_statsbomb_xg  \
# index                                                ...
# 2088   4cbd1088-1580-43f5-8b09-58efabb753ff       1  ...                NaN
# ...

# %%
df_test3 = pd.read_parquet("data-storage/xThreat_data_v3_euros2020.parquet", engine='fastparquet')
df_test3.head()
# Out:
#              x       y  possession_kept  possession  possession_length  \
# index
# 2088   13.8250   6.375             True           3                  0
# 9       2.8875  10.795             True           3                  2
# 2089    6.9125  30.770             True           3                  3
# 10      7.9625  33.065             True           3                  4
# 2090   17.2375  40.715             True           3                  5
#
#        chain_length  previous_deleted  match_id  \
# index
# 2088              0              True   3788741
# 9                 1             False   3788741
# 2089              2             False   3788741
# 10                3             False   3788741
# 2090              4             False   3788741
#
#                                          id  period  ...  shot_outcome  \
# index                                                ...
# 2088   4cbd1088-1580-43f5-8b09-58efabb753ff       1  ...          None
# ...

# %%
df_test_new = pd.read_parquet("data-storage/xThreat_data_v4.parquet", engine='fastparquet')

# %%
df_test_new.head()
# Out:
#             x      y  possession_kept  possession  possession_length  \
# index
# 2229   42.875  45.90             True           2                  0
# 8      47.250  51.00             True           2                  1
# 2230   50.750  64.60             True           2                  2
# 9      49.000  65.45             True           2                  3
# 2231   33.250  55.25             True           2                  4
#
#        chain_length  previous_deleted  match_id  \
# index
# 2229              0              True      9575
# 8                 1             False      9575
# 2230              2             False      9575
# 9                 3             False      9575
# 2231              4             False      9575
#
#                                          id  period  ...  shot_statsbomb_xg  \
# index                                                ...
# 2229   d32867d0-0ad7-457b-84ed-d8d36170a7a8       1  ...                NaN
# ...

# %%
from statsbombpy import sb
competition_id = 7
season_id = 27
# Get the matches for Ligue 1 2015/2016
Ligue_1_season_1516 = sb.matches(competition_id=competition_id, season_id=season_id)

match_list = Ligue_1_season_1516['match_id'].tolist()
# Out:
# c:\Users\kwvanarem\Documents\GitHub\xthreat-error-quantification\.venv\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
df_test_new_ligue = df_test_new[df_test_new['match_id'].isin(match_list)].copy()

# %%
df_test_new_ligue.to_parquet("data-storage/xThreat_data_v4_ligue1_1516.parquet", engine='fastparquet', index=False)

# %%
df_test_new_ligue.columns.tolist()
# Out:
# ['x',
#  'y',
#  'possession_kept',
#  'possession',
#  'possession_length',
#  'chain_length',
#  'previous_deleted',
#  'match_id',
#  'id',
#  'period',
#  'player_id',
#  'type',
#  'shot_outcome',
#  'shot_statsbomb_xg',
#  'pass_height',
#  'under_pressure',
#  'position',
#  'next_type',
#  'next_x',
#  'next_y',
#  'next_under_pressure',
#  'next_team_id',
#  'next_player_id']

# %%
import pandas as pd
data_path = 'data-storage/xThreat_data_v4_ligue1_1516.parquet' # version 4 has player position added
df_events = pd.read_parquet(data_path, engine='fastparquet')
df_events['shot'] = ~df_events['shot_outcome'].isna()
df_events['goal'] = df_events['shot_outcome'] == 'Goal'
df_events.drop(columns=['id', 'shot_outcome', 'possession'], inplace=True)
df_size_bytes = df_events.memory_usage(deep=True).sum()
df_size_mb = df_size_bytes / (1024 ** 2)  # Convert to MB

print(f"DataFrame size: {df_size_mb:.2f} MB")
# Out:
# DataFrame size: 190.87 MB

# %%
df_events.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 604704 entries, 0 to 604703
# Data columns (total 22 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   x                    604704 non-null  float64
#  1   y                    604704 non-null  float64
#  2   possession_kept      604704 non-null  bool
#  3   possession_length    604704 non-null  int64
#  4   chain_length         604704 non-null  int64
#  5   previous_deleted     604704 non-null  bool
#  6   match_id             604704 non-null  int64
#  7   period               604704 non-null  int64
#  8   player_id            604704 non-null  float64
#  9   type                 604704 non-null  object
#  10  shot_statsbomb_xg    4090 non-null    float64
#  11  pass_height          317283 non-null  object
#  12  under_pressure       162038 non-null  float64
#  13  position             604704 non-null  object
#  14  next_type            604704 non-null  object
# ...
