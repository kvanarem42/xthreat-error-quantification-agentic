# %%
from statsbombpy import sb
import warnings
import pandas as pd

from datadownloader import DataDownloader
from datasetcreator import columns_to_keep, DataSetCreator

# %% [markdown]
# # Download all games

# %%
# Call statsbombpy API to get all free competitions
free_comps = sb.competitions()
free_comps.head()
# Out:
# c:\Users\kwvanarem\Documents\GitHub\xthreat-error-quantification\.venv\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#    competition_id  season_id country_name        competition_name  \
# 0               9        281      Germany           1. Bundesliga
# 1               9         27      Germany           1. Bundesliga
# 2            1267        107       Africa  African Cup of Nations
# 3              16          4       Europe        Champions League
# 4              16          1       Europe        Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                       True
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated           match_updated_360  \
# 0   2023/2024  2024-07-15T14:15:54.671676  2024-07-15T14:17:00.877356
# 1   2015/2016  2024-05-19T11:11:14.192381                        None
# 2        2023  2024-06-13T07:51:02.452825                        None
# 3   2018/2019  2024-06-12T07:44:38.559714     2021-06-13T16:17:31.694
# 4   2017/2018  2024-02-13T02:35:28.134882     2021-06-13T16:17:31.694
#
#           match_available_360             match_available
# 0  2024-07-15T14:17:00.877356  2024-07-15T14:15:54.671676
# 1                        None  2024-05-19T11:11:14.192381
# 2                        None  2024-06-13T07:51:02.452825
# 3                        None  2024-06-12T07:44:38.559714
# 4                        None  2024-02-13T02:35:28.134882

# %%
free_comps
# Out:
#     competition_id  season_id   country_name        competition_name  \
# 0                9        281        Germany           1. Bundesliga
# 1                9         27        Germany           1. Bundesliga
# 2             1267        107         Africa  African Cup of Nations
# 3               16          4         Europe        Champions League
# 4               16          1         Europe        Champions League
# ..             ...        ...            ...                     ...
# 69              55         43         Europe               UEFA Euro
# 70              35         75         Europe      UEFA Europa League
# 71              53        106         Europe       UEFA Women's Euro
# 72              72        107  International       Women's World Cup
# 73              72         30  International       Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# 1                male              False                      False
# 2                male              False                       True
# 3                male              False                      False
# 4                male              False                      False
# ..                ...                ...                        ...
# 69               male              False                       True
# 70               male              False                      False
# 71             female              False                       True
# 72             female              False                       True
# 73             female              False                       True
#
#    season_name               match_updated           match_updated_360  \
# 0    2023/2024  2024-07-15T14:15:54.671676  2024-07-15T14:17:00.877356
# 1    2015/2016  2024-05-19T11:11:14.192381                        None
# 2         2023  2024-06-13T07:51:02.452825                        None
# 3    2018/2019  2024-06-12T07:44:38.559714     2021-06-13T16:17:31.694
# 4    2017/2018  2024-02-13T02:35:28.134882     2021-06-13T16:17:31.694
# ..         ...                         ...                         ...
# 69        2020  2024-04-16T12:44:40.558402  2024-04-16T12:47:18.505110
# 70   1988/1989  2024-02-12T14:45:05.702250     2021-06-13T16:17:31.694
# 71        2022  2024-02-13T13:27:17.178263  2024-02-13T13:30:52.820588
# 72        2023  2024-07-14T16:59:48.469596  2024-07-14T17:01:38.887279
# 73        2019  2024-02-13T09:41:26.379767     2021-06-13T16:17:31.694
#
#            match_available_360             match_available
# 0   2024-07-15T14:17:00.877356  2024-07-15T14:15:54.671676
# 1                         None  2024-05-19T11:11:14.192381
# 2                         None  2024-06-13T07:51:02.452825
# 3                         None  2024-06-12T07:44:38.559714
# 4                         None  2024-02-13T02:35:28.134882
# ..                         ...                         ...
# 69  2024-04-16T12:47:18.505110  2024-04-16T12:44:40.558402
# 70                        None  2024-02-12T14:45:05.702250
# 71  2024-02-13T13:30:52.820588  2024-02-13T13:27:17.178263
# 72  2024-07-14T17:01:38.887279  2024-07-14T16:59:48.469596
# 73                        None  2024-02-13T09:41:26.379767
#
# [74 rows x 12 columns]

# %%
free_comps['competition_name'].unique().tolist()
# Out:
# ['1. Bundesliga',
#  'African Cup of Nations',
#  'Champions League',
#  'Copa America',
#  'Copa del Rey',
#  "FA Women's Super League",
#  'FIFA U20 World Cup',
#  'FIFA World Cup',
#  'Indian Super league',
#  'La Liga',
#  'Liga Profesional',
#  'Ligue 1',
#  'Major League Soccer',
#  'North American League',
#  'NWSL',
#  'Premier League',
#  'Serie A',
#  'UEFA Euro',
#  'UEFA Europa League',
#  "UEFA Women's Euro",
#  "Women's World Cup"]

# %%
competition_ids = [
    11, # LaLiga
    2, # Premier League
    12, # Serie A
    7, # Ligue 1
    9, # Bundesliga
]

# %%
warnings.filterwarnings("ignore", message="credentials were not supplied")
for competition_id in competition_ids:
    free_seasons = free_comps[free_comps['competition_id'] == competition_id]
    downloader = DataDownloader(free_seasons, directory='.\\data-storage\\raw_data')
    downloader.download_store_seasons()
# Out:
# 2020_2021
# 100%|██████████| 35/35 [00:17<00:00,  1.97it/s]
# Downloaded, processed, and stored all available events of La Liga (2020/2021) in 0.30 minutes.
# 2019_2020
# 100%|██████████| 33/33 [00:21<00:00,  1.51it/s]
# Downloaded, processed, and stored all available events of La Liga (2019/2020) in 0.37 minutes.
# 2018_2019
# 100%|██████████| 34/34 [00:20<00:00,  1.63it/s]
# Downloaded, processed, and stored all available events of La Liga (2018/2019) in 0.35 minutes.
# 2017_2018
# 100%|██████████| 36/36 [00:20<00:00,  1.79it/s]
# Downloaded, processed, and stored all available events of La Liga (2017/2018) in 0.34 minutes.
# 2016_2017
# 100%|██████████| 34/34 [00:16<00:00,  2.04it/s]
# Downloaded, processed, and stored all available events of La Liga (2016/2017) in 0.28 minutes.
# 2015_2016
# 100%|██████████| 380/380 [03:06<00:00,  2.04it/s]
# Downloaded, processed, and stored all available events of La Liga (2015/2016) in 3.11 minutes.
# 2014_2015
# 100%|██████████| 38/38 [00:21<00:00,  1.74it/s]
# Downloaded, processed, and stored all available events of La Liga (2014/2015) in 0.37 minutes.
# 2013_2014
# 100%|██████████| 31/31 [00:18<00:00,  1.71it/s]
# Downloaded, processed, and stored all available events of La Liga (2013/2014) in 0.31 minutes.
# 2012_2013
# 100%|██████████| 32/32 [00:15<00:00,  2.10it/s]
# Downloaded, processed, and stored all available events of La Liga (2012/2013) in 0.26 minutes.
# 2011_2012
# 100%|██████████| 37/37 [00:17<00:00,  2.15it/s]
# Downloaded, processed, and stored all available events of La Liga (2011/2012) in 0.29 minutes.
# 2010_2011
# 100%|██████████| 33/33 [00:14<00:00,  2.23it/s]
# Downloaded, processed, and stored all available events of La Liga (2010/2011) in 0.25 minutes.
# 2009_2010
# 100%|██████████| 35/35 [00:16<00:00,  2.16it/s]
# Downloaded, processed, and stored all available events of La Liga (2009/2010) in 0.27 minutes.
# 2008_2009
# 100%|██████████| 31/31 [00:13<00:00,  2.30it/s]
# Downloaded, processed, and stored all available events of La Liga (2008/2009) in 0.23 minutes.
# 2007_2008
# 100%|██████████| 28/28 [00:12<00:00,  2.22it/s]
# Downloaded, processed, and stored all available events of La Liga (2007/2008) in 0.21 minutes.
# 2006_2007
# 100%|██████████| 26/26 [00:11<00:00,  2.27it/s]
# Downloaded, processed, and stored all available events of La Liga (2006/2007) in 0.19 minutes.
# 2005_2006
# 100%|██████████| 17/17 [00:07<00:00,  2.34it/s]
# Downloaded, processed, and stored all available events of La Liga (2005/2006) in 0.12 minutes.
# 2004_2005
# 100%|██████████| 7/7 [00:02<00:00,  2.50it/s]
# Downloaded, processed, and stored all available events of La Liga (2004/2005) in 0.05 minutes.
# 1973_1974
# 100%|██████████| 1/1 [00:00<00:00,  2.12it/s]
# Downloaded, processed, and stored all available events of La Liga (1973/1974) in 0.01 minutes.
# 2015_2016
#  91%|█████████ | 346/380 [03:07<00:18,  1.84it/s]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       3 free_seasons = free_comps[free_comps['competition_id'] == competition_id]
#       4 downloader = DataDownloader(free_seasons, directory='.\\data-storage\\raw_data')
# ----> 5 downloader.download_store_seasons()
#
# File c:\Users\kwvanarem\Documents\GitHub\xthreat-error-quantification\1-data-preparation\datadownloader.py:74, in DataDownloader.download_store_seasons(self)
#      72 for i in range(len(self.seasons_df)):
#      73     season_series = self.seasons_df.iloc[i]
# ---> 74     self.download_store_season(season_series)
#
# File c:\Users\kwvanarem\Documents\GitHub\xthreat-error-quantification\1-data-preparation\datadownloader.py:67, in DataDownloader.download_store_season(self, season_series)
#      65 for i in tqdm(range(len(df_matches))):
#      66     match_series = df_matches.iloc[i]
# ---> 67     self.download_store_match(match_series, directory)
#      69 print(f"Downloaded, processed, and stored all available events of {season_series['competition_name']} ({season_series['season_name']}) in {(time.time() - begin_time)/60:.2f} minutes.")
#
# File c:\Users\kwvanarem\Documents\GitHub\xthreat-error-quantification\1-data-preparation\datadownloader.py:42, in DataDownloader.download_store_match(self, match_series, directory)
#      41 def download_store_match(self, match_series: pd.Series, directory: str) -> None:
# ---> 42     df_match_events = self.download_match_events(match_series['match_id'])
#      43     df_match_events = self.clean_match_events(df_match_events)
#      44     match_file_name = self.make_file_name(match_series)
#
# File c:\Users\kwvanarem\Documents\GitHub\xthreat-error-quantification\1-data-preparation\datadownloader.py:18, in DataDownloader.download_match_events(self, match_id)
#      17 def download_match_events(self, match_id: int) -> pd.DataFrame:
# ---> 18     df_match_events = sb.events(match_id=match_id).sort_values('index')
#      19     return df_match_events
#
# File c:\Users\kwvanarem\Documents\GitHub\xthreat-error-quantification\.venv\Lib\site-packages\statsbombpy\sb.py:111, in events(match_id, split, filters, fmt, flatten_attrs, creds, include_360_metrics)
#     109     events = api_client.events(match_id, creds=creds)
#     110 else:
# --> 111     events = public.events(match_id)
#     113 if include_360_metrics:
#     114     frames = _360_frames(match_id, creds=creds)
#
# File c:\Users\kwvanarem\Documents\GitHub\xthreat-error-quantification\.venv\Lib\site-packages\statsbombpy\public.py:38, in events(match_id)
#      36 def events(match_id: int) -> dict:
#      37     path = OPEN_DATA_PATHS["events"].format(match_id=match_id)
# ---> 38     events = get_response(path)
#      39     events = ents.events(events, match_id)
#      40     return events
#
# File c:\Users\kwvanarem\Documents\GitHub\xthreat-error-quantification\.venv\Lib\site-packages\statsbombpy\public.py:9, in get_response(path)
#       7 def get_response(path):
#       8     response = req.get(path)
# ----> 9     response.raise_for_status()
#      10     data = response.json()
#      11     return data
#
# File c:\Users\kwvanarem\Documents\GitHub\xthreat-error-quantification\.venv\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://raw.githubusercontent.com/statsbomb/open-data/master/data/events
/s]c:\Users\kwvanarem\Documents\Onderzoek\xthreat-error-quantification\.venv\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#  98%|█████████▊| 50/51 [00:23<00:00,  1.48it/s]c:\Users\kwvanarem\Documents\Onderzoek\xthreat-error-quantification\.venv\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# 100%|██████████| 51/51 [00:24<00:00,  2.08it/s]
# Downloaded, processed, and stored all available events of UEFA Euro (2020) in 0.41 minutes.

# %% [markdown]
# # Create data set

# %%
# data_set_creator = DataSetCreator(
#     ['type', 'x', 'y', 'under_pressure', 'team_id', 'player_id'],
#     storage_directory='./',
# )
# data_set_creator.create_data_set('./data-storage/raw_data/', 'extra_filtered_data.parquet')
# Out:
# Processing files:   0%|          | 0/2442 [00:00<?, ?it/s]
# Processing files: 100%|██████████| 2442/2442 [20:06<00:00,  2.02it/s]

# %%
# data_set_creator = DataSetCreator(
#     ['type', 'x', 'y', 'under_pressure', 'team_id', 'player_id'],
#     storage_directory='./',
# )
# data_set_creator.create_data_set('./data-storage/raw_data/', 'test.parquet')
# Out:
# Processing files: 100%|██████████| 2442/2442 [5:49:41<00:00,  8.59s/it]

# %%
data_path_data_set = './data-storage/xThreat_data_v3.parquet'

# %%
data_set_creator = DataSetCreator(
    ['type', 'x', 'y', 'under_pressure', 'team_id', 'player_id'],
    storage_directory='./',
)
data_set_creator.create_data_set('./data-storage/raw_data/', data_path_data_set)
# Out:
# Processing files:   0%|          | 0/2442 [00:00<?, ?it/s]
# Processing files: 100%|██████████| 2442/2442 [20:46<00:00,  1.96it/s]

# %% [markdown]
# Should be 2442

# %%
df_events = pd.read_parquet(data_path_data_set, engine='fastparquet')

df_events['shot'] = ~df_events['shot_outcome'].isna()
df_events['goal'] = df_events['shot_outcome'] == 'Goal'

df_events.drop(columns=['id', 'shot_outcome', 'possession'], inplace=True)
df_size_bytes = df_events.memory_usage(deep=True).sum()
df_size_mb = df_size_bytes / (1024 ** 2)  # Convert to MB
print(f"DataFrame size: {df_size_mb:.2f} MB")
print(f"DataFrame shape: {df_events.shape}")

del df_events
# Out:
# DataFrame size: 999.40 MB
# DataFrame shape: (4038776, 21)

# %%
# df_events = pd.read_parquet('extra_filtered_data.parquet', engine='fastparquet')

# df_events['shot'] = ~df_events['shot_outcome'].isna()
# df_events['goal'] = df_events['shot_outcome'] == 'Goal'

# df_events.drop(columns=['id', 'shot_outcome', 'possession'], inplace=True)
# df_size_bytes = df_events.memory_usage(deep=True).sum()
# df_size_mb = df_size_bytes / (1024 ** 2)  # Convert to MB
# print(f"DataFrame size: {df_size_mb:.2f} MB")
# print(f"DataFrame shape: {df_events.shape}")
# Out:
# DataFrame size: 1039.54 MB
# DataFrame shape: (3985659, 21)

# %%
# df_events.isna().sum()
# Out:
# x                            0
# y                            0
# possession_kept              0
# possession_length            0
# chain_length                 0
# previous_deleted             0
# match_id                     0
# period                       0
# player_id                    0
# type                         0
# shot_statsbomb_xg      3956799
# pass_height            1911526
# under_pressure         2963142
# next_type                    0
# next_x                       0
# next_y                       0
# next_under_pressure    2962808
# next_team_id                 0
# next_player_id               0
# shot                         0
# goal                         0
# dtype: int64

# %%
data_set_creator = DataSetCreator(
    ['type', 'x', 'y', 'under_pressure', 'team_id', 'player_id'],
    storage_directory='./',
)
data_set_creator.create_data_set('./data-storage/raw_data_euros2020/', './data-storage/xThreat_data_v3_euros2020.parquet')
# Out:
# Processing files: 100%|██████████| 51/51 [00:20<00:00,  2.47it/s]
